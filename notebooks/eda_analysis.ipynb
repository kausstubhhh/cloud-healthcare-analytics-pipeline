# %%
from google.cloud import bigquery
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.cloud import bigquery

client = bigquery.Client()

# %%
query = """
SELECT *
FROM `healthcare-analytics-kaust.pharmacy_analytics.prescriptions_features`
"""

df = client.query(query).to_dataframe()
df.head()
# Out:
# C:\Users\kaust\projects\cloud-healthcare-analytics-pipeline\venv\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    record_id  height_inches  weight_pounds        bmi
# 0         98          63.43         123.10  21.509185
# 1         23          63.48          97.90  17.079069
# 2        110          63.84         127.19  21.939288
# 3         40          64.05         106.71  18.286146
# 4        156          64.13         106.11  18.137990

# %%
plt.savefig("../figures/height_distribution.png")

# %%
df.dtypes
# Out:
# record_id          Int64
# height_inches    float64
# weight_pounds    float64
# bmi              float64
# dtype: object

# %%
df.shape
# Out:
# (200, 4)

# %%
plt.hist(df["height_inches"], bins=20)
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x="height_inches",
    bins=30,
    kde=True
)

plt.title("Height Distribution")
plt.xlabel("Height (inches)")
plt.ylabel("Frequency")

plt.savefig("../figures/height_distribution.png")

plt.show()
